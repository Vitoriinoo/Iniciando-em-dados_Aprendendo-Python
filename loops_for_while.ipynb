# %% [markdown]
# <a href="https://colab.research.google.com/github/Vitoriinoo/Iniciando-em-dados_Aprendendo-Python/blob/main/loops_for_while.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
# <img width="80%" src="https://user-images.githubusercontent.com/73097560/115834477-dbab4500-a447-11eb-908a-139a6edaec5c.gif"/>
#
# <div align="center">
#
# <img src="https://raw.githubusercontent.com/devicons/devicon/master/icons/python/python-original.svg" alt="Python" width="80" height="80"/>
#
# <h1 style="font-size: 2.5em; color: #e6e6e6; margin: 10px 0;">
# </h1>
#
# <h2 style="font-size: 2.5em; color: #e6e6e6; margin: 10px 0;">
#    Iniciando em Data Science: Aprendendo Python
# </h2>
#
# <h3 style="color: #a8b2d1; font-weight: 400; margin: 10px 0;">
#   PhD. Julles Mitoura
# </h3>
#
# <p style="margin: 10px 0;">
#   <img src="https://img.shields.io/badge/Python-3776AB?style=for-the-badge&logo=python&logoColor=white" alt="Python"/>
#   <img src="https://img.shields.io/badge/Data_Science-FF6F00?style=for-the-badge&logo=jupyter&logoColor=white" alt="Data Science"/>
#   <img src="https://img.shields.io/badge/Alura-0078D4?style=for-the-badge&logo=&logoColor=white" alt="Alura"/>
# </p>
#
# <img width="80%" src="https://user-images.githubusercontent.com/73097560/115834477-dbab4500-a447-11eb-908a-139a6edaec5c.gif"/>
#
# </div>

# %% [markdown]
# # **Módulo 4**: Estruturas de Repetição
#
# ---
# ## Aula 1: Laços while e for
#
# Nesta aula, falaremos sobre:
#
# - O que são estruturas de repetição (laços)
# - Como usar `while` para repetir código
# - Como usar `for` para iterar sobre sequências
# - Quando usar cada tipo de laço
# - Como evitar loops infinitos
#
# Este é um tópico essencial pois estruturas de repetição permitem automatizar tarefas repetitivas e processar coleções de dados.
#
# ---

# %% [markdown]
# ## 1. O que são Estruturas de Repetição?
#
# **Estruturas de repetição** (também chamadas de **laços** ou **loops**) permitem executar um bloco de código várias vezes, sem precisar escrever o mesmo código repetidamente.
#
# Pense em situações do dia a dia:
# - Contar de 1 até 10
# - Imprimir os nomes de todos os alunos
# - Repetir uma ação até que uma condição seja atendida
# - Processar uma lista de itens
#
# Em Python, temos dois tipos principais de laços:
# - **`while`**: repete enquanto uma condição for verdadeira
# - **`for`**: repete para cada item de uma sequência

# %% [markdown]
# ## 2. Laço while (Enquanto)
#
# O laço `while` repete um bloco de código **enquanto** uma condição for verdadeira.
#
# **Sintaxe:**
# ```python
# while condição:
#     # código que será executado enquanto a condição for True
# ```
#
# **Importante:** A condição é verificada **antes** de cada iteração. Se for `False` desde o início, o código dentro do `while` nunca será executado!

# %%
# Exemplo 1: Contar de 1 até 5
# Crie uma variável contador = 1
# Use um laço while para repetir enquanto contador <= 5
# Dentro do laço, imprima o valor do contador e incremente-o
# Após o laço, imprima "Fim do laço"
# Escreva seu código aqui

contador = 1
while contador <= 5:
  print(contador)

  contador = contador + 1

print("Fim do laço")

# %%
# Exemplo 2: Contar números pares até 10
# Crie uma variável numero = 2
# Use um laço while para repetir enquanto numero <= 10
# Dentro do laço, imprima que o número é par e incremente numero de 2 em 2
# Após o laço, imprima "Fim!"
# Escreva seu código aqui
numero = 2

while numero <= 10:
  print(numero)
  numero = numero + 2

print("Fim")
# Out:
# 2
# 4
# 6
# 8
# 10
# Fim

# %% [markdown]
# ### 2.1 Cuidado: Loops Infinitos!
#
# Um **loop infinito** acontece quando a condição do `while` nunca se torna `False`. Isso faz o programa rodar para sempre!
#
# **Exemplo de loop infinito (NÃO execute por muito tempo!):**
# ```python
# contador = 1
# while contador <= 5:  # contador nunca muda!
#     print(contador)
#     # Falta: contador = contador + 1
# ```
#
# **Sempre certifique-se de que a condição do `while` eventualmente se tornará `False`!**

# %%
# Exemplo correto: Contar até 3 (com incremento)
# Crie uma variável contador = 1
# Use um laço while para repetir enquanto contador <= 3
# IMPORTANTE: Dentro do laço, imprima o contador e incremente-o
# Após o laço, imprima "Laço finalizado corretamente"
# Escreva seu código aqui

contador = 1

while contador <= 5:
  print(contador)
  contador = contador + 1
print("Laço finalizado corretamente")
# Out:
# 1
# 2
# 3
# 4
# 5
# Laço finalizado corretamente

# %% [markdown]
# ## 3. Laço for (Para)
#
# O laço `for` é usado para iterar (percorrer) sobre uma sequência de valores. É muito útil quando sabemos quantas vezes queremos repetir algo.
#
# **Sintaxe:**
# ```python
# for variavel in sequencia:
#     # código que será executado para cada item da sequência
# ```
#
# A variável recebe cada valor da sequência, um por vez.

# %%
# Exemplo 1: Iterar sobre uma lista de números
# Crie uma lista numeros = [1, 2, 3, 4, 5]
# Use um laço for para iterar sobre cada número da lista
# Dentro do laço, imprima cada número
# Após o laço, imprima "Fim do laço"
# Escreva seu código aqui
numeros = [1,2,3,4,5]

for item in numeros:
  print(item)
print("Fim do laço")
# Out:
# 1
# 2
# 3
# 4
# 5
# Fim do laço

# %%
texto = "Python"
for letra in texto:
  print(letra)
# Out:
# P
# y
# t
# h
# o
# n

# %%
# Exemplo 2: Iterar sobre uma lista de nomes
# Crie uma lista nomes = ["Ana", "Bruno", "Carlos", "Diana"]
# Use um laço for para iterar sobre cada nome da lista
# Dentro do laço, imprima uma saudação para cada nome
# Após o laço, imprima "Todos foram cumprimentados!"
# Escreva seu código aqui

nomes = ["Ana", "Bruno", "Carlos", "Diana"]

for nome in nomes:
  print(f"Olá {nome}, tudo bem?")

print("Todos foram cumprimentados")
# Out:
# Olá Ana, tudo bem?
# Olá Bruno, tudo bem?
# Olá Carlos, tudo bem?
# Olá Diana, tudo bem?
# Todos foram cumprimentados

# %% [markdown]
# ## 4. Comparando while e for
#
# ### Quando usar `while`?
# - Quando não sabemos quantas vezes vamos repetir
# - Quando queremos repetir até que uma condição seja atendida
# - Quando a condição depende de algo que muda durante a execução
#
# ### Quando usar `for`?
# - Quando sabemos quantos itens vamos processar
# - Quando queremos iterar sobre uma sequência (lista, string, etc.)
# - Quando queremos processar cada item de uma coleção
#
# **Dica:** Na maioria dos casos, `for` é mais seguro e mais fácil de usar!

# %%
# Exemplo: Mesma tarefa com while e for
# FORMA 1: Use while para contar de 1 até 5
# FORMA 2: Use for com a lista [1, 2, 3, 4, 5] para fazer o mesmo
# Compare qual forma é mais simples e menos propensa a erros
# Escreva seu código aqui

#WHILE:
print("Com o loop while:\n")

numero = 1
while numero <= 5:
  print(numero)
  numero = numero + 1

print(f"\nAgora com o loop for:\n")
numeros = [1,2,3,4,5]
for numero in numeros:
  print(numero)
# Out:
# Com o loop while:
#
# 1
# 2
# 3
# 4
# 5
#
# Agora com o loop for:
#
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## 5. Resumo da Aula
#
# Nesta aula você aprendeu:
#
# **Laço `while`:**
# - Repete enquanto a condição for `True`
# - Útil quando não sabemos quantas repetições
# - Cuidado com loops infinitos!
#
# **Laço `for`:**
# - Itera sobre uma sequência
# - Mais seguro e fácil de usar
# - Ideal para processar coleções
#
# **Quando usar cada um:**
# - `while`: quando a condição muda durante a execução
# - `for`: quando sabemos o que vamos iterar
#
# **Dica:** Sempre incremente/altere a variável de controle no `while` para evitar loops infinitos!
#
# Na próxima aula, vamos aprender sobre a função `range()` e controle de fluxo!
